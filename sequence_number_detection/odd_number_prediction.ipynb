# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
sequence = np.arange(1, 100, 2)
X = sequence[:-1]
y = sequence[1:]

# %%
model = Sequential()
model.add(Dense(10, input_dim=1, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X, y, epochs=200, batch_size=1, verbose=1)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 1s 2ms/step - loss: 4624.8560
# Epoch 2/200
# 49/49 [==============================] - 0s 2ms/step - loss: 3722.0227
# Epoch 3/200
# 49/49 [==============================] - 0s 2ms/step - loss: 2941.7903
# Epoch 4/200
# 49/49 [==============================] - 0s 1ms/step - loss: 2296.4309
# Epoch 5/200
# 49/49 [==============================] - 0s 1ms/step - loss: 1746.4634
# Epoch 6/200
# 49/49 [==============================] - 0s 1ms/step - loss: 1297.6506
# Epoch 7/200
# 49/49 [==============================] - 0s 1ms/step - loss: 933.7984
# Epoch 8/200
# 49/49 [==============================] - 0s 2ms/step - loss: 649.6909
# Epoch 9/200
# 49/49 [==============================] - 0s 2ms/step - loss: 432.7360
# Epoch 10/200
# 49/49 [==============================] - 0s 1ms/step - loss: 278.6059
# Epoch 11/200
# 49/49 [==============================] - 0s 1ms/step - loss: 170.6086
# Epoch 12/200
# ...

# %%
next_digit = model.predict(np.array([55]))
print("Next digit prediction:", np.rint(next_digit))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Next digit prediction: [[57.]]

# %%
type(next_digit)
# Out:
# numpy.ndarray

# %%
np.round(next_digit, 2)
# Out:
# array([[101.]], dtype=float32)

# %%
 np.int_(next_digit)
# Out:
# array([[100]])

# %%
import os

# %%
model.save("odd_number.h5")

# %%
from tensorflow.keras.models import load_model

# %%
loaded_model=load_model("odd_number.h5")
next_digit = loaded_model.predict(np.array([100]))
print(next_digit)
# Out:
# 1/1 [==============================] - 0s 77ms/step
# [[101.99926]]

# %%
next_digit = loaded_model.predict(np.array([99]))
print(next_digit)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# [[100.99929]]

# %%
next_digit = loaded_model.predict(np.array([115]))
print(next_digit)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [[116.99866]]
